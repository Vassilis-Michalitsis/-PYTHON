# %% [markdown]
# <a href="https://colab.research.google.com/github/Vassilis-Michalitsis/-PYTHON/blob/main/Copy_of_exercise4MICHALITSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Άσκηση 1
#
# Γράψτε ένα προγραμματάκι που θα αθροίζει όλους τους περιττούς αριθμούς από το 1 έως και το 100 και θα τυπώνει το τελικό άθροισμα.
#
# Hints & tips:
#
# - περιττοί είναι οι αριθμοί που το υπόλοιπο της διαίρεσής τους με το 2 ΔΕΝ είναι 0 (x % 2 != 0)
# - μπορούμε αρχικά να ορίσουμε ότι το άθροισμα των περιττών αριθμών είναι 0 (sum = 0)
# - στη συνέχεια μπορούμε να φτιάξουμε μια λούπα που θα κάνει τα εξής:
#   - για κάθε αριθμό από το 1 ως και το 100
#   - αν το υπόλοιπο της διαίρεσης του αριθμού με το 2 δεν είναι 0
#   - το άθροισμα θα αυξάνεται κατά τον αριθμό

# %%
# Υπολογισμός αθροίσματος όλων των περιττών αριθμών από το 1 έως 100
sum_odd = 0

for num in range(1, 101):  # Εύρος από 1 έως 100
    if num % 2 != 0:  # Ελέγχει αν είναι περιττός
        sum_odd += num

print("Το άθροισμα όλων των περιττών αριθμών από το 1 έως το 100 είναι:", sum_odd)
# Out:
# Το άθροισμα όλων των περιττών αριθμών από το 1 έως το 100 είναι: 2500

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 2
#
# Τροποποιήστε το παραπάνω πρόγραμμα έτσι ώστε, εκτός από το άθροισμα των περιττών, να υπολογίζει και να τυπώνει ΚΑΙ:
# - το πλήθος των περιττών αριθμών
# - το άθροισμα των ζυγών αριθμών στο ίδιο εύρος
# - το πλήθος των ζυγών αριθμών

# %%
sum_odd = 0
count_odd = 0
sum_even = 0
count_even = 0

for num in range(1, 101):
    if num % 2 != 0:  # Περιττός αριθμός
        sum_odd += num
        count_odd += 1
    else:  # Ζυγός αριθμός
        sum_even += num
        count_even += 1

print("Άθροισμα περιττών:", sum_odd)
print("Πλήθος περιττών:", count_odd)
print("Άθροισμα ζυγών:", sum_even)
print("Πλήθος ζυγών:", count_even)
# Out:
# Άθροισμα περιττών: 2500
# Πλήθος περιττών: 50
# Άθροισμα ζυγών: 2550
# Πλήθος ζυγών: 50

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 3
#
# Αντιγράψτε εδώ τον κώδικα που γράψατε για την 1η Άσκηση του notebook "exercise3.ipynb".
#
# Θα χρειαστούμε τη λίστα με τα λεξικά των άρθρων.
#
# Χρησιμοποιώντας τη βιβλιοθήκη Pandas, φτιάξτε ένα dataframe με τα δεδομένα της λίστας με τα λεξικά των άρθρων.
# Στη συνέχεια, εμφανίστε το dataframe στην οθόνη.
#
# **Hints & tips**:
# - για να χρησιμοποιήσετε τη βιβλιοθήκη pandas πρέπει πρώτα να την εισάγετε: import pandas as pd
# - η δημιουργία ενός dataframe από μια λίστα με λεξικά, γίνεται με την εξής σύνταξη: df = pd.DataFrame(<όνομα λίστας με λεξικά>)

# %%
import pandas as pd

# Παράδειγμα λίστας με λεξικά
articles = [
    {"title": "Article 1", "author": "Author A", "views": 100},
    {"title": "Article 2", "author": "Author B", "views": 200},
    {"title": "Article 3", "author": "Author C", "views": 300}
]

# Δημιουργία DataFrame
df = pd.DataFrame(articles)

# Εμφάνιση DataFrame
print(df)
# Out:
#        title    author  views
# 0  Article 1  Author A    100
# 1  Article 2  Author B    200
# 2  Article 3  Author C    300

# %%
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 4 (intro)
#
# Στο site "ourworldindata.org" παρέχονται πάρα πολλά δεδομένα και γραφήματα για διάφορα topics για όλες τις χώρες του κόσμου.
#
# Για παράδειγμα, στη σελίδα https://ourworldindata.org/explorers/covid?Metric=Excess+mortality+%28estimates%29&Interval=Cumulative&Relative+to+population=false&country=USA~BRA~JPN~DEU, παρέχονται δεδομένα και γραφήματα σχετικά με την Covid-19.
#
# Αν επισκεφθείτε την παραπάνω σελίδα, επάνω αριστερά, υπάρχει ένας υπερσύνδεσμος με το κείμενο "Download this dataset". Εάν τον πατήσετε θα οδηγηθείτε στη σελίδα με τα datasets για τον covid.
#
# Πιο κάτω, σ' αυτή τη σελίδα, υπάρχει η ενότητα "Download data", με πολλά κουμπάκια download.
#
# Όταν πατήσετε κάποιο download μεταφέρεστε στη σελίδα του raw αρχείου csv με τα δεδομένα.
#
# Μπορούμε να φέρουμε αυτά τα δεδομένα σε ένα dataframe στην Python, με την παρακάτω εντολή:

# %%
covid_df = pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/cases_deaths/cases_deaths.csv")
covid_df
# Out:
#             country        date  new_cases  total_cases  new_deaths  \
# 0       Afghanistan  2020-01-04        0.0            0         0.0
# 1       Afghanistan  2020-01-05        0.0            0         0.0
# 2       Afghanistan  2020-01-06        0.0            0         0.0
# 3       Afghanistan  2020-01-07        0.0            0         0.0
# 4       Afghanistan  2020-01-08        0.0            0         0.0
# ...             ...         ...        ...          ...         ...
# 472846     Zimbabwe  2025-03-12        0.0       266410         0.0
# 472847     Zimbabwe  2025-03-13        0.0       266410         0.0
# 472848     Zimbabwe  2025-03-14        0.0       266410         0.0
# 472849     Zimbabwe  2025-03-15        0.0       266410         0.0
# 472850     Zimbabwe  2025-03-16        0.0       266410         0.0
#
#         total_deaths  weekly_cases  weekly_deaths  weekly_pct_growth_cases  \
# 0                  0           NaN            NaN                      NaN
# 1                  0           NaN            NaN                      NaN
# 2                  0           NaN            NaN                      NaN
# 3                  0           NaN            NaN                      NaN
# 4                  0           NaN            NaN                      NaN
# ...              ...           ...            ...                      ...
# 472846          5740           0.0            0.0                      NaN
# 472847          5740           0.0            0.0                      NaN
# 472848          5740           0.0            0.0                      NaN
# 472849          5740           0.0            0.0                      NaN
# 472850          5740           0.0            0.0                      NaN
#
#         weekly_pct_growth_deaths  ...  cfr_100_cases  cfr_short_term  \
# 0                            NaN  ...            NaN             NaN
# 1                            NaN  ...            NaN             NaN
# 2                            NaN  ...            NaN             NaN
# 3                            NaN  ...            NaN             NaN
# 4                            NaN  ...            NaN             NaN
# ...                          ...  ...            ...             ...
# 472846                       NaN  ...       2.154574             NaN
# 472847                       NaN  ...       2.154574             NaN
# 472848                       NaN  ...       2.154574             NaN
# 472849                       NaN  ...       2.154574             NaN
# 472850                       NaN  ...       2.154574             NaN
#
#         days_since_100_total_cases  days_since_5_total_deaths  \
# 0                            -86.0                      -91.0
# 1                            -85.0                      -90.0
# 2                            -84.0                      -89.0
# 3                            -83.0                      -88.0
# 4                            -82.0                      -87.0
# ...                            ...                        ...
# 472846                      1751.0                     1833.0
# 472847                      1752.0                     1834.0
# 472848                      1753.0                     1835.0
# 472849                      1754.0                     1836.0
# 472850                      1755.0                     1837.0
#
#         days_since_1_total_cases_per_million  \
# 0                                      -81.0
# 1                                      -80.0
# 2                                      -79.0
# 3                                      -78.0
# 4                                      -77.0
# ...                                      ...
# 472846                                1793.0
# 472847                                1794.0
# 472848                                1795.0
# 472849                                1796.0
# 472850                                1797.0
#
#         days_since_0_1_total_deaths_per_million  \
# 0                                         -91.0
# 1                                         -90.0
# 2                                         -89.0
# 3                                         -88.0
# 4                                         -87.0
# ...                                         ...
# 472846                                   1833.0
# 472847                                   1834.0
# 472848                                   1835.0
# 472849                                   1836.0
# 472850                                   1837.0
#
#         days_since_100_total_cases_and_5m_pop  total_deaths_last12m  \
# 0                                       -86.0                   NaN
# 1                                       -85.0                   NaN
# 2                                       -84.0                   NaN
# 3                                       -83.0                   NaN
# 4                                       -82.0                   NaN
# ...                                       ...                   ...
# 472846                                 1751.0                   0.0
# 472847                                 1752.0                   0.0
# 472848                                 1753.0                   0.0
# 472849                                 1754.0                   0.0
# 472850                                 1755.0                   0.0
#
#         total_deaths_per_100k_last12m  total_deaths_per_million_last12m
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 472846                            0.0                               0.0
# 472847                            0.0                               0.0
# 472848                            0.0                               0.0
# 472849                            0.0                               0.0
# 472850                            0.0                               0.0
#
# [472851 rows x 40 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 4 (actual part)
#
# Βρείτε από το ourworldindata.org ένα dataset που σας ενδιαφέρει και ανοίξτε το σαν dataframe.

# %%
import pandas as pd

# URL του dataset από το "ourworldindata.org"
url = "https://catalog.ourworldindata.org/garden/covid/latest/cases_deaths/cases_deaths.csv"

# Φόρτωση δεδομένων σε DataFrame
covid_df = pd.read_csv(url)

# Εμφάνιση πρώτων γραμμών
print(covid_df.head())
# Out:
#        country        date  new_cases  total_cases  new_deaths  total_deaths  \
# 0  Afghanistan  2020-01-04        0.0            0         0.0             0
# 1  Afghanistan  2020-01-05        0.0            0         0.0             0
# 2  Afghanistan  2020-01-06        0.0            0         0.0             0
# 3  Afghanistan  2020-01-07        0.0            0         0.0             0
# 4  Afghanistan  2020-01-08        0.0            0         0.0             0
#
#    weekly_cases  weekly_deaths  weekly_pct_growth_cases  \
# 0           NaN            NaN                      NaN
# 1           NaN            NaN                      NaN
# 2           NaN            NaN                      NaN
# 3           NaN            NaN                      NaN
# 4           NaN            NaN                      NaN
#
#    weekly_pct_growth_deaths  ...  cfr_100_cases  cfr_short_term  \
# 0                       NaN  ...            NaN             NaN
# 1                       NaN  ...            NaN             NaN
# 2                       NaN  ...            NaN             NaN
# 3                       NaN  ...            NaN             NaN
# 4                       NaN  ...            NaN             NaN
#
#    days_since_100_total_cases  days_since_5_total_deaths  \
# 0                       -86.0                      -91.0
# 1                       -85.0                      -90.0
# 2                       -84.0                      -89.0
# 3                       -83.0                      -88.0
# 4                       -82.0                      -87.0
#
#    days_since_1_total_cases_per_million  \
# 0                                 -81.0
# 1                                 -80.0
# 2                                 -79.0
# 3                                 -78.0
# 4                                 -77.0
#
#    days_since_0_1_total_deaths_per_million  \
# 0                                    -91.0
# 1                                    -90.0
# 2                                    -89.0
# 3                                    -88.0
# 4                                    -87.0
#
#    days_since_100_total_cases_and_5m_pop  total_deaths_last12m  \
# 0                                  -86.0                   NaN
# 1                                  -85.0                   NaN
# 2                                  -84.0                   NaN
# 3                                  -83.0                   NaN
# 4                                  -82.0                   NaN
#
#    total_deaths_per_100k_last12m  total_deaths_per_million_last12m
# 0                            NaN                               NaN
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
#
# [5 rows x 40 columns]
